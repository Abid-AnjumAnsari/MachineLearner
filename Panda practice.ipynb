# %%
import pandas as pd
cs=pd.read_csv('data\car-sales.csv')
cs
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
cs.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
cs.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
col=cs.columns
col
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
cs.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
cs
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
cs.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
cs.info
# Out:
# <bound method DataFrame.info of      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00>

# %%
cs.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
cpd.series
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-5daba4f09d2c> in <module>()
# ----> 1 cs.pd.series
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'pd'

# %%
len(cs)
# Out:
# 10

# %% [markdown]
# ## viewing and selecting the data

# %%
pd.crosstab(cs['Make'],cs['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

cs['Odometer (KM)'].plot()

# %%
cs['Odometer (KM)'].hist()

# %%
cs['Price'].dtype
# Out:
# dtype('O')

# %%
cs['Price'].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-6fc587ef990f> in <module>()
# ----> 1 cs['Price'].plot()
#
# C:\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2739                            colormap=colormap, table=table, yerr=yerr,
#    2740                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2741                            **kwds)
#    2742     __call__.__doc__ = plot_series.__doc__
#    2743
#
# ...

# %%
df[df.columns[1:]] = df[df.columns[1:]].replace('[\$,]', '', regex=True).astype(float)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4   400000.0
# 1   Honda    Red          87899      4   500000.0
# 2  Toyota   Blue          32549      3   700000.0
# 3     BMW  Black          11179      5  2200000.0
# 4  Nissan  White         213095      4   350000.0
# 5  Toyota  Green          99213      4   450000.0
# 6   Honda   Blue          45698      4   750000.0
# 7   Honda   Blue          54738      4   700000.0
# 8  Toyota  White          60000      4   625000.0
# 9  Nissan  White          31600      4   970000.0

# %%
cs['Price']=cs['Price'].replace('[\$,]','',regex=True).astype(float)

# %%
cs
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
cs['Price'].plot()

# %% [markdown]
# ## manipulating data

# %%
cs['Colour']=cs['Colour'].str.lower()
cs
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  white         150043      4   4000.0
# 1   Honda    red          87899      4   5000.0
# 2  Toyota   blue          32549      3   7000.0
# 3     BMW  black          11179      5  22000.0
# 4  Nissan  white         213095      4   3500.0
# 5  Toyota  green          99213      4   4500.0
# 6   Honda   blue          45698      4   7500.0
# 7   Honda   blue          54738      4   7000.0
# 8  Toyota  white          60000      4   6250.0
# 9  Nissan  white          31600      4   9700.0

# %%
cs1=pd.read_csv('data\car-sales-missing-data.csv')
cs1
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
cs1["Odometer"].fillna(cs1['Odometer'].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
cs1
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
cs1["Odometer"]=cs1["Odometer"].fillna(cs1['Odometer'].mean())
cs1
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
cs1.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
cs1
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
cs2=cs1.dropna()

# %%
cs2
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
cs2
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
cs2.to_csv('car-sales-missing-nonan.csv')

# %%
seats=pd.Series([5,54,5,5,5,5])
cs1['Seats']=seats

# %%
cs1
# Out:
#      Make Colour       Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0
# 1   Honda    Red   87899.000000    4.0   $5,000   54.0
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0
# 3     BMW  Black   11179.000000    5.0  $22,000    5.0
# 4  Nissan  White  213095.000000    4.0   $3,500    5.0
# 5  Toyota  Green   92302.666667    4.0   $4,500    5.0
# 6   Honda    NaN   92302.666667    4.0   $7,500    NaN
# 7   Honda   Blue   92302.666667    4.0      NaN    NaN
# 8  Toyota  White   60000.000000    NaN      NaN    NaN
# 9     NaN  White   31600.000000    4.0   $9,700    NaN

# %%
Fuel_economy=[5,6,9,0,43,65]
cs1['Fuel_eco']=Fuel_economy

for list exact length is required
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-bd6a90373af1> in <module>()
#       1 Fuel_economy=[5,6,9,0,43,65]
# ----> 2 cs1['Fuel_eco']=Fuel_economy
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3114         else:
#    3115             # set column
# -> 3116             self._set_item(key, value)
#    3117
#    3118     def _setitem_slice(self, key, value):
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3189
#    3190         self._ensure_valid_index(value)
# -> 3191         value = self._sanitize_column(key, value)
#    3192         NDFrame._set_item(self, key, value)
#    3193
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3386
#    3387             # turn me into an ndarray
# ...

# %%
Fuel_economy=[5,6,9,0,43,65,4,5,6,7]
cs1['Fuel_eco']=Fuel_economy

# %%
cs1
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Fuel_eco
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0         5
# 1   Honda    Red   87899.000000    4.0   $5,000   54.0         6
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0         9
# 3     BMW  Black   11179.000000    5.0  $22,000    5.0         0
# 4  Nissan  White  213095.000000    4.0   $3,500    5.0        43
# 5  Toyota  Green   92302.666667    4.0   $4,500    5.0        65
# 6   Honda    NaN   92302.666667    4.0   $7,500    NaN         4
# 7   Honda   Blue   92302.666667    4.0      NaN    NaN         5
# 8  Toyota  White   60000.000000    NaN      NaN    NaN         6
# 9     NaN  White   31600.000000    4.0   $9,700    NaN         7

# %%
cs1.drop("Fuel_eco",axis=1,inplace=True)

# %%
cs1
# Out:
#      Make Colour       Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0
# 1   Honda    Red   87899.000000    4.0   $5,000   54.0
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0
# 3     BMW  Black   11179.000000    5.0  $22,000    5.0
# 4  Nissan  White  213095.000000    4.0   $3,500    5.0
# 5  Toyota  Green   92302.666667    4.0   $4,500    5.0
# 6   Honda    NaN   92302.666667    4.0   $7,500    NaN
# 7   Honda   Blue   92302.666667    4.0      NaN    NaN
# 8  Toyota  White   60000.000000    NaN      NaN    NaN
# 9     NaN  White   31600.000000    4.0   $9,700    NaN

# %%
inplace jo hota h agar permanent change chahiye without assignment
assignment krenge to inplace ka jrurat nhi h

# %% [markdown]
# ## sampling

# %%
cs1.sample(frac=1)
# Out:
#      Make Colour       Odometer  Doors    Price  Seats
# 8  Toyota  White   60000.000000    NaN      NaN    NaN
# 6   Honda    NaN   92302.666667    4.0   $7,500    NaN
# 1   Honda    Red   87899.000000    4.0   $5,000   54.0
# 5  Toyota  Green   92302.666667    4.0   $4,500    5.0
# 7   Honda   Blue   92302.666667    4.0      NaN    NaN
# 4  Nissan  White  213095.000000    4.0   $3,500    5.0
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0
# 9     NaN  White   31600.000000    4.0   $9,700    NaN
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0
# 3     BMW  Black   11179.000000    5.0  $22,000    5.0

# %%
cs1
# Out:
#      Make Colour       Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0
# 1   Honda    Red   87899.000000    4.0   $5,000   54.0
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0
# 3     BMW  Black   11179.000000    5.0  $22,000    5.0
# 4  Nissan  White  213095.000000    4.0   $3,500    5.0
# 5  Toyota  Green   92302.666667    4.0   $4,500    5.0
# 6   Honda    NaN   92302.666667    4.0   $7,500    NaN
# 7   Honda   Blue   92302.666667    4.0      NaN    NaN
# 8  Toyota  White   60000.000000    NaN      NaN    NaN
# 9     NaN  White   31600.000000    4.0   $9,700    NaN

# %%
cs1=cs1.sample(frac=1)

# %%
cs1
# Out:
#      Make Colour       Odometer  Doors    Price  Seats
# 4  Nissan  White  213095.000000    4.0   $3,500    5.0
# 6   Honda    NaN   92302.666667    4.0   $7,500    NaN
# 9     NaN  White   31600.000000    4.0   $9,700    NaN
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0
# 8  Toyota  White   60000.000000    NaN      NaN    NaN
# 3     BMW  Black   11179.000000    5.0  $22,000    5.0
# 5  Toyota  Green   92302.666667    4.0   $4,500    5.0
# 1   Honda    Red   87899.000000    4.0   $5,000   54.0
# 7   Honda   Blue   92302.666667    4.0      NaN    NaN

# %%
expt=cs1.sample(frac=0.2)

# %%
expt
# Out:
#      Make Colour      Odometer  Doors   Price  Seats
# 9     NaN  White  31600.000000    4.0  $9,700    NaN
# 5  Toyota  Green  92302.666667    4.0  $4,500    5.0

# %%
#now we want to reset the index but not the shuffling
cs1.reset_index(inplace=True,drop=True)

# %%
cs1
# Out:
#    level_0  index    Make Colour       Odometer  Doors    Price  Seats
# 0        0      4  Nissan  White  213095.000000    4.0   $3,500    5.0
# 1        1      6   Honda    NaN   92302.666667    4.0   $7,500    NaN
# 2        2      9     NaN  White   31600.000000    4.0   $9,700    NaN
# 3        3      2  Toyota   Blue   92302.666667    3.0   $7,000    5.0
# 4        4      0  Toyota  White  150043.000000    4.0   $4,000    5.0
# 5        5      8  Toyota  White   60000.000000    NaN      NaN    NaN
# 6        6      3     BMW  Black   11179.000000    5.0  $22,000    5.0
# 7        7      5  Toyota  Green   92302.666667    4.0   $4,500    5.0
# 8        8      1   Honda    Red   87899.000000    4.0   $5,000   54.0
# 9        9      7   Honda   Blue   92302.666667    4.0      NaN    NaN
